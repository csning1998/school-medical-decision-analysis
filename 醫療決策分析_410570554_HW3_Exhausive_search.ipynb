# %% [markdown]
# # Ch 4. 醫療物資疫苗配送路線最佳化
#
# 本作業以「醫療物資與疫苗配送」為應用情境，讓同學透過多種演算法解決 旅行推銷員問題（TSP, Traveling Salesman Problem），體驗如何將理論演算法應用於實際醫療物流的最佳化問題。完成本作業後，你將能夠：
#
# 1. 實作並比較四種最佳化方法（窮舉法、動態規劃法、最近鄰居法、基因演算法）
# 2. 以圖表與數據分析不同演算法的特性與效率差異
# 3. 反思演算法於真實醫療配送場景中的應用與限制

# %% [markdown]
# ## Section 0. 預備知識與資料準備

# %% [markdown]
# ### Step. 準備資料
#
# 拿到資料第一件事情，就是要載入資料。因為給定資料集有兩個，所以要檢查兩筆資料

# %%
import pandas as pd
df_hospital = pd.read_csv("hospitals.csv")
df_hospital.head()
# Out:
#       x      y
# 0   0.0    9.3
# 1  34.8   67.3
# 2  53.2  100.0
# 3  42.2   59.6
# 4  30.7   37.9

# %% [markdown]
# ## Section 1. Exhaustive Search
#
# > _嘗試以窮舉方式找出最短路徑。若計算量過大、無法在合理時間內完成，請估算理論上所需的計算次數與時間，並討論其可行性_

# %% [markdown]
# 針對窮舉法，執行

# %%
import itertools
import time
import numpy as np
from scipy.spatial.distance import cdist

# --- 1. Setup ---
A = df_hospital[["x", "y"]].values
D = cdist(A, A, metric="euclidean")

H = list(range(1, 16))
P_gen = itertools.permutations(H)

d_min = float("inf")
p_min = []
c = 0

# %%
# --- 2. Main Loop ---
print("Starting Exhaustive Search")
t_start = time.perf_counter()

for p in P_gen:
    # NumPy array for indexing
    p_curr = np.array([0] + list(p) + [0])

    idx_a = p_curr[:-1]  # from
    idx_b = p_curr[1:]  # to

    d_curr = D[idx_a, idx_b].sum()

    # find best dist
    if d_curr < d_min:
        d_min = d_curr
        p_min = list(p_curr)

    c += 1

    # Print progress update per 1 billion paths
    if c % 1_000_000_000 == 0:
        t_elapsed = time.perf_counter() - t_start
        print(f"Checked {c // 1_000_000_000} billion paths... (Time: {t_elapsed:.2f}s)")


t_end = time.perf_counter()

print("Exhaustive Search Results:\n")
print(f"Total paths checked: {c}")
print(f"Shortest Distance: {d_min}")
print(f"Shortest Path: {p_min}")
print(f"Total Time: {t_end - t_start:.4f} seconds")
# Out:
# Starting Exhaustive Search
# Checked 1 billion paths... (Time: 1852.93s)
# Checked 2 billion paths... (Time: 3691.76s)
# Checked 3 billion paths... (Time: 5538.67s)
# Checked 4 billion paths... (Time: 7397.20s)
# Checked 5 billion paths... (Time: 9265.18s)
# Checked 6 billion paths... (Time: 11123.56s)
# Checked 7 billion paths... (Time: 13012.56s)
# Checked 8 billion paths... (Time: 14901.73s)
# Checked 9 billion paths... (Time: 16784.20s)
# Checked 10 billion paths... (Time: 18675.95s)
# Checked 11 billion paths... (Time: 20544.11s)
# Checked 12 billion paths... (Time: 22355.71s)
# Checked 13 billion paths... (Time: 24160.83s)
# Checked 14 billion paths... (Time: 25968.94s)
# Checked 15 billion paths... (Time: 27777.33s)
# Checked 16 billion paths... (Time: 29594.17s)
# Checked 17 billion paths... (Time: 31414.15s)
# Checked 18 billion paths... (Time: 33223.73s)
# Checked 19 billion paths... (Time: 35032.61s)
# Checked 20 billion paths... (Time: 36845.34s)
# Checked 89 billion paths... (Time: 163919.35s)
# Checked 90 billion paths... (Time: 165751.16s)
# Checked 91 billion paths... (Time: 167579.19s)
# Checked 92 billion paths... (Time: 169404.17s)
# Checked 93 billion paths... (Time: 171227.80s)
# Checked 94 billion paths... (Time: 173051.91s)
# Checked 95 billion paths... (Time: 174884.43s)
# Checked 96 billion paths... (Time: 176716.05s)
# Checked 97 billion paths... (Time: 178547.68s)
# Checked 98 billion paths... (Time: 180368.57s)
# Checked 99 billion paths... (Time: 182193.39s)
# Checked 100 billion paths... (Time: 184015.92s)
# Checked 101 billion paths... (Time: 185841.32s)
# Checked 102 billion paths... (Time: 187674.12s)
# Checked 103 billion paths... (Time: 189499.66s)
# Checked 104 billion paths... (Time: 191326.42s)
# Checked 105 billion paths... (Time: 193157.95s)
# Checked 106 billion paths... (Time: 194985.96s)
# Checked 107 billion paths... (Time: 196816.12s)
# Checked 108 billion paths... (Time: 198666.47s)
# Checked 109 billion paths... (Time: 200526.16s)
# Checked 110 billion paths... (Time: 202379.90s)
# Checked 111 billion paths... (Time: 204240.00s)
# Checked 112 billion paths... (Time: 206102.70s)
# Checked 113 billion paths... (Time: 207964.36s)
# Checked 114 billion paths... (Time: 209820.10s)
# Checked 115 billion paths... (Time: 211682.32s)
# Checked 116 billion paths... (Time: 213545.98s)
# Checked 117 billion paths... (Time: 215405.37s)
# Checked 118 billion paths... (Time: 217265.92s)
# Checked 119 billion paths... (Time: 219124.99s)
# Checked 120 billion paths... (Time: 220983.67s)
# Checked 121 billion paths... (Time: 222845.58s)
# Checked 122 billion paths... (Time: 224695.21s)
# Checked 123 billion paths... (Time: 226557.43s)
# Checked 124 billion paths... (Time: 228413.60s)
# Checked 125 billion paths... (Time: 230276.41s)
# Checked 126 billion paths... (Time: 232117.08s)
# Checked 127 billion paths... (Time: 233972.79s)
# Checked 128 billion paths... (Time: 235814.42s)
# Checked 129 billion paths... (Time: 237644.08s)
# Checked 130 billion paths... (Time: 239466.90s)
# Checked 131 billion paths... (Time: 241298.19s)
# Checked 132 billion paths... (Time: 243119.33s)
# Checked 133 billion paths... (Time: 244946.81s)
# Checked 134 billion paths... (Time: 246759.97s)
# Checked 135 billion paths... (Time: 248585.94s)
# Checked 136 billion paths... (Time: 250412.25s)
# Checked 137 billion paths... (Time: 252238.44s)
# Checked 138 billion paths... (Time: 254067.73s)
# Checked 139 billion paths... (Time: 255898.89s)
# Checked 140 billion paths... (Time: 257721.24s)
# Checked 141 billion paths... (Time: 259552.49s)
# Checked 142 billion paths... (Time: 261373.98s)
# Checked 143 billion paths... (Time: 263210.90s)
# Checked 144 billion paths... (Time: 265035.11s)
# Checked 145 billion paths... (Time: 266861.90s)
# Checked 146 billion paths... (Time: 268685.29s)
# Checked 147 billion paths... (Time: 270516.33s)
# Checked 148 billion paths... (Time: 272340.06s)
# Checked 149 billion paths... (Time: 274174.00s)
# Checked 150 billion paths... (Time: 275997.00s)
# Checked 151 billion paths... (Time: 277827.40s)
# Checked 152 billion paths... (Time: 279650.23s)
# Checked 153 billion paths... (Time: 281477.85s)
# Checked 154 billion paths... (Time: 283296.08s)
# Checked 155 billion paths... (Time: 285127.65s)
# Checked 156 billion paths... (Time: 286957.25s)
# Checked 157 billion paths... (Time: 288787.22s)
# Checked 158 billion paths... (Time: 290614.96s)
# Checked 159 billion paths... (Time: 292438.51s)
# Checked 160 billion paths... (Time: 294261.87s)
# Checked 161 billion paths... (Time: 296089.48s)
# Checked 162 billion paths... (Time: 297900.98s)
# Checked 163 billion paths... (Time: 299726.11s)
# Checked 164 billion paths... (Time: 301544.78s)
# Checked 165 billion paths... (Time: 303364.40s)
# Checked 166 billion paths... (Time: 305183.83s)
# Checked 167 billion paths... (Time: 306995.90s)
# Checked 168 billion paths... (Time: 308846.57s)
# Checked 169 billion paths... (Time: 310691.21s)
# Checked 170 billion paths... (Time: 312538.49s)
# Checked 171 billion paths... (Time: 314386.87s)
# Checked 172 billion paths... (Time: 316223.16s)
# Checked 173 billion paths... (Time: 318056.24s)
# Checked 174 billion paths... (Time: 319890.62s)
# Checked 175 billion paths... (Time: 321757.91s)
# Checked 176 billion paths... (Time: 323640.84s)
# Checked 177 billion paths... (Time: 325472.75s)
# Checked 178 billion paths... (Time: 327298.12s)
# Checked 179 billion paths... (Time: 329131.95s)
# Checked 180 billion paths... (Time: 330950.20s)
# Checked 181 billion paths... (Time: 332779.87s)
# Checked 182 billion paths... (Time: 334594.80s)
# Checked 183 billion paths... (Time: 336420.72s)
# Checked 184 billion paths... (Time: 338242.49s)
# Checked 185 billion paths... (Time: 340065.96s)
# Checked 186 billion paths... (Time: 341892.66s)
# Checked 187 billion paths... (Time: 343737.76s)
# Checked 188 billion paths... (Time: 345560.34s)
# Checked 189 billion paths... (Time: 347384.49s)
# Checked 190 billion paths... (Time: 349210.90s)
# Checked 191 billion paths... (Time: 351038.45s)
# Checked 192 billion paths... (Time: 352855.92s)
# Checked 193 billion paths... (Time: 354687.32s)
# Checked 194 billion paths... (Time: 356504.11s)
# Checked 195 billion paths... (Time: 358334.51s)
# Checked 196 billion paths... (Time: 360159.74s)
# Checked 197 billion paths... (Time: 361987.98s)
# Checked 198 billion paths... (Time: 363801.56s)
# Checked 199 billion paths... (Time: 365632.39s)
# Checked 200 billion paths... (Time: 367457.91s)
# Checked 201 billion paths... (Time: 369290.22s)
# Checked 202 billion paths... (Time: 371103.69s)
# Checked 203 billion paths... (Time: 372947.04s)
# Checked 204 billion paths... (Time: 374779.28s)
# Checked 205 billion paths... (Time: 376607.89s)
# Checked 206 billion paths... (Time: 378433.68s)
# Checked 207 billion paths... (Time: 380264.74s)
# Checked 208 billion paths... (Time: 382090.40s)
# Checked 209 billion paths... (Time: 383919.16s)
# Checked 210 billion paths... (Time: 385744.43s)
# Checked 211 billion paths... (Time: 387564.57s)
# Checked 212 billion paths... (Time: 389388.02s)
# Checked 213 billion paths... (Time: 391214.47s)
# Checked 214 billion paths... (Time: 393029.91s)
# Checked 215 billion paths... (Time: 394873.98s)
# Checked 216 billion paths... (Time: 396735.90s)
# Checked 217 billion paths... (Time: 398595.52s)
# Checked 218 billion paths... (Time: 400452.17s)
# Checked 219 billion paths... (Time: 402318.40s)
# Checked 220 billion paths... (Time: 404198.25s)
# Checked 221 billion paths... (Time: 406087.50s)
# Checked 222 billion paths... (Time: 407947.25s)
# Checked 223 billion paths... (Time: 409836.39s)
